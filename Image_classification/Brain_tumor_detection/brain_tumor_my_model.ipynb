# %% [markdown]
# <a href="https://colab.research.google.com/github/H0sseinR0stami/DeepLearningProjects/blob/main/Image_classification/Brain_tumor_detection/brain_tumor_my_model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Model building

# %%
from keras.layers import Conv2D , MaxPool2D , Dropout , Flatten , Dense , BatchNormalization , GlobalAvgPool2D
from keras.models import Sequential
from keras.preprocessing.image import ImageDataGenerator
import keras

# %% [markdown]
# CNN model

# %%
model = Sequential()

model.add(Conv2D(filters = 16 ,kernel_size=(3,3), activation = 'relu', input_shape=(224, 224, 3)))

model.add(Conv2D(filters = 32 ,kernel_size=(3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 64 ,kernel_size=(3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2)))


model.add(Conv2D(filters = 128 ,kernel_size=(3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Conv2D(filters = 256 ,kernel_size=(3,3), activation = 'relu'))
model.add(MaxPool2D(pool_size=(2,2)))

model.add(Dropout(rate=0.25))

model.add(Flatten())
model.add(Dense(units=64 , activation='relu'))
model.add(Dropout(rate=0.25))
model.add(Dense(units=1 , activation= 'sigmoid'))

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d (Conv2D)             (None, 222, 222, 16)      448
#
#  conv2d_1 (Conv2D)           (None, 220, 220, 32)      4640
#
#  max_pooling2d (MaxPooling2D  (None, 110, 110, 32)     0
#  )
#
#  conv2d_2 (Conv2D)           (None, 108, 108, 64)      18496
#
#  max_pooling2d_1 (MaxPooling  (None, 54, 54, 64)       0
#  2D)
#
#  conv2d_3 (Conv2D)           (None, 52, 52, 128)       73856
#
#  max_pooling2d_2 (MaxPooling  (None, 26, 26, 128)      0
#  2D)
#
#  conv2d_4 (Conv2D)           (None, 24, 24, 256)       295168
#
#  max_pooling2d_3 (MaxPooling  (None, 12, 12, 256)      0
#  2D)
#
#  dropout (Dropout)           (None, 12, 12, 256)       0
#
#  flatten (Flatten)           (None, 36864)             0
#
#  dense (Dense)               (None, 64)                2359360
#
#  dropout_1 (Dropout)         (None, 64)                0
#
# ...

# %%
model.compile(optimizer='adam', loss=keras.losses.binary_crossentropy, metrics= ['accuracy'])

# %% [markdown]
# Preparing Data useing Data Generator

# %%
def preprocessingImages_train(path):
  """
  input : path
  output: Pre processed images
  """
  image_data = ImageDataGenerator(zoom_range= 0.2, shear_range=0.2, rescale=1/255, horizontal_flip=True)
  image = image_data.flow_from_directory(directory=path , target_size=(224,224), batch_size=32, class_mode='binary')
  return image

# %%
path = "/content/drive/MyDrive/Colab_Notebooks/project1/brain_train_data/train"
train_data = preprocessingImages_train(path)
# Out:
# Found 3215 images belonging to 2 classes.

# %%
def preprocessingImages_test(path):
  """
  input : path
  output: Pre processed images
  """
  image_data = ImageDataGenerator(rescale=1/255)
  image = image_data.flow_from_directory(directory=path , target_size=(224,224), batch_size=32, class_mode='binary')
  return image

# %%
path = "/content/drive/MyDrive/Colab_Notebooks/project1/brain_train_data/test"
test_data = preprocessingImages_test(path)
# Out:
# Found 680 images belonging to 2 classes.

# %%
path = "/content/drive/MyDrive/Colab_Notebooks/project1/brain_train_data/validation"
val_data = preprocessingImages_test(path)
# Out:
# Found 680 images belonging to 2 classes.

# %%
# early stopping

es = keras.callbacks.EarlyStopping(monitor = "val_accuracy" , min_delta = 0.01 , patience = 6 , verbose =1 , mode = 'auto' )

# model check point

mc = keras.callbacks.ModelCheckpoint(monitor="val_accuracy", filepath="/content/drive/MyDrive/Colab_Notebooks/project1/1.brain-tumor/brain_tumor_my_model.h6", verbose=1, save_best_only= True , mode='auto')

cd = [es,mc]

# %% [markdown]
# Model training

# %%
hs = model.fit_generator(generator=train_data, steps_per_epoch=16 , epochs=30 , verbose=1 , validation_data= val_data , callbacks=cd )
# Out:
# Epoch 1/30
# 16/16 [==============================] - ETA: 0s - loss: 0.7106 - accuracy: 0.5078
# Epoch 00001: val_accuracy improved from -inf to 0.54706, saving model to /content/drive/MyDrive/Colab_Notebooks/project1/1.brain-tumor/brain_tumor_my_model.h6
# INFO:tensorflow:Assets written to: /content/drive/MyDrive/Colab_Notebooks/project1/1.brain-tumor/brain_tumor_my_model.h6/assets
# 16/16 [==============================] - 262s 16s/step - loss: 0.7106 - accuracy: 0.5078 - val_loss: 0.6866 - val_accuracy: 0.5471
# Epoch 2/30
# 16/16 [==============================] - ETA: 0s - loss: 0.6852 - accuracy: 0.5547
# Epoch 00002: val_accuracy did not improve from 0.54706
# 16/16 [==============================] - 93s 6s/step - loss: 0.6852 - accuracy: 0.5547 - val_loss: 0.6785 - val_accuracy: 0.5471
# Epoch 3/30
# 16/16 [==============================] - ETA: 0s - loss: 0.6745 - accuracy: 0.5605
# ...

# %% [markdown]
# Model Graphical Interpretation

# %%
h = hs.history
h.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %%
plt.plot(h['accuracy'])
plt.plot(h['val_accuracy'] , c= 'red')

plt.title("acc vs val-acc")
# Out:
# Text(0.5, 1.0, 'acc vs val-acc')

# %%
plt.plot(h['loss'])
plt.plot(h['val_loss'] , c= 'red')

plt.title("acc vs val-acc")
# Out:
# Text(0.5, 1.0, 'acc vs val-acc')

# %% [markdown]
# Model accuracy

# %%
from keras.models import load_model
model= load_model("/content/drive/MyDrive/Colab_Notebooks/project1/1.brain-tumor/brain_tumor_my_model.h6")

# %%
acc= model.evaluate_generator(test_data)[1]
print(f"the accuracy of our model is {acc*100} %")
# Out:
# the accuracy of our model is 87.35294342041016 %

# %%
from keras.preprocessing import image

# %%
train_data.class_indices
# Out:
# {'Brain_Tumor': 0, 'Healthy': 1}

# %%
path = '/content/drive/MyDrive/Colab_Notebooks/project1/brain_train_data/brain_tumor_dataset/Brain_Tumor/Cancer (1384).jpg'

img = image.load_img(path,target_size=(224,224))
i = image.img_to_array(img)/255
input_arr = np.expand_dims(i, axis = 0)
pred = (model.predict(input_arr)>0.5).astype("int32")[0][0]
if pred == 0:
  print("Brain is having Tumor")
else:
  print("Brain is not having Tumor")

plt.imshow(input_arr[0])
plt.show
# Out:
# Brain is having Tumor
# <function matplotlib.pyplot.show>

# %%
path = '/content/drive/MyDrive/Colab_Notebooks/project1/brain_train_data/brain_tumor_dataset/Healthy/Not Cancer  (1972).jpg'

img = image.load_img(path,target_size=(224,224))
i = image.img_to_array(img)/255
input_arr = np.expand_dims(i, axis = 0)
pred = (model.predict(input_arr)>0.5).astype("int32")[0][0]
if pred == 0:
  print("Brain is having Tumor")
else:
  print("Brain is not having Tumor")

plt.imshow(input_arr[0])
plt.show
# Out:
# Brain is not having Tumor
# <function matplotlib.pyplot.show>
